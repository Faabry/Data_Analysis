# %% [markdown]
# <h1> Portland Crimes Analysis </h1>

# %%
# Versão Python
from platform import python_version
print(f"Versão Python para este projeto: {python_version()}")
# Out:
# Versão Python para este projeto: 3.10.5

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
# Versão dos pacotes
# %reload_ext watermark
# %watermark -a "Airton Fabre" --iversions
# Out:
# Author: Airton Fabre
#
# pandas    : 2.0.3
# matplotlib: 3.5.2
# seaborn   : 0.11.2
# numpy     : 1.23.1

# %% [markdown]
# <h1> Carregando o Conjunto de Dados </h1>

# %%
df = pd.read_csv("data/Crimes.csv", sep="\t")
df.head(3)
# Out:
#    Unnamed: 0                     Address CaseNumber CrimeAgainst  \
# 0      491800  8800 BLOCK OF SE FLAVEL ST  23-171766     Property
# 1      475141     800 BLOCK OF SW 4TH AVE  23-915199     Property
# 2      475143     800 BLOCK OF SW 4TH AVE  23-915330     Property
#
#   Neighborhood   OccurDate  OccurTime   OffenseCategory  \
# 0        Lents  2023-06-30       2100  Larceny Offenses
# 1     Downtown  2023-06-30        730  Larceny Offenses
# 2     Downtown  2023-06-30       1550         Vandalism
#
#                 OffenseType  OpenDataLat  OpenDataLon  OpenDataX  OpenDataY  \
# 0  Theft From Motor Vehicle    45.468464  -122.572201  7670548.0   663706.0
# 1  Theft From Motor Vehicle    45.517507  -122.677045  7644142.0   682288.0
# 2                 Vandalism    45.517507  -122.677045  7644142.0   682288.0
#
#    ReportDate  OffenseCount
# 0  2023-06-30             1
# 1  2023-06-30             1
# 2  2023-06-30             1

# %% [markdown]
# <h1> Análise Exploratória </h1>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499915 entries, 0 to 499914
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       499915 non-null  int64
#  1   Address          457678 non-null  object
#  2   CaseNumber       499915 non-null  object
#  3   CrimeAgainst     499915 non-null  object
#  4   Neighborhood     483451 non-null  object
#  5   OccurDate        499915 non-null  object
#  6   OccurTime        499915 non-null  int64
#  7   OffenseCategory  499915 non-null  object
#  8   OffenseType      499915 non-null  object
#  9   OpenDataLat      446531 non-null  float64
#  10  OpenDataLon      446531 non-null  float64
#  11  OpenDataX        446531 non-null  float64
#  12  OpenDataY        446531 non-null  float64
#  13  ReportDate       499915 non-null  object
#  14  OffenseCount     499915 non-null  int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 57.2+ MB

# %%
# Valores ausentes
for col in df.columns:
    if df[col].isna().sum() > 0:
        print(f"{col}: {df[col].isna().sum()} valores ausentes.")
        print(f"O que representa {round(df[col].isna().sum() / len(df), 2)}% de valores ausentes")
        print("-" * 25)
# Out:
# Address: 42237 valores ausentes.
# O que representa 0.08% de valores ausentes
# -------------------------
# Neighborhood: 16464 valores ausentes.
# O que representa 0.03% de valores ausentes
# -------------------------
# OpenDataLat: 53384 valores ausentes.
# O que representa 0.11% de valores ausentes
# -------------------------
# OpenDataLon: 53384 valores ausentes.
# O que representa 0.11% de valores ausentes
# -------------------------
# OpenDataX: 53384 valores ausentes.
# O que representa 0.11% de valores ausentes
# -------------------------
# OpenDataY: 53384 valores ausentes.
# O que representa 0.11% de valores ausentes
# -------------------------

# %%
df.loc[df["Address"].isna()]
# Out:
#         Unnamed: 0 Address   CaseNumber CrimeAgainst    Neighborhood  \
# 52          470562     NaN  23-X5852372       Person  Rose City Park
# 53          470550     NaN  23-X5851985       Person             NaN
# 55          470561     NaN  23-X5852364       Person      Centennial
# 56          470560     NaN  23-X5852363       Person      Centennial
# 78          470567     NaN  23-X5853802       Person     Arbor Lodge
# ...            ...     ...          ...          ...             ...
# 499874           1     NaN  15-X4282999       Person    Buckman West
# 499875         156     NaN  15-X4292739     Property            Reed
# 499876         155     NaN  15-X4292739       Person            Reed
# 499902        3539     NaN  15-X4762771       Person             NaN
# 499907        1272     NaN  15-X4351729       Person       Homestead
#
#          OccurDate  OccurTime   OffenseCategory     OffenseType  OpenDataLat  \
# 52      2023-06-30       2325  Assault Offenses  Simple Assault          NaN
# 53      2023-06-30       1535  Assault Offenses  Simple Assault          NaN
# 55      2023-06-30       2200  Assault Offenses    Intimidation          NaN
# 56      2023-06-30       2038  Assault Offenses    Intimidation          NaN
# 78      2023-06-30       2230      Sex Offenses            Rape          NaN
# ...            ...        ...               ...             ...          ...
# 499874  2015-05-01       2143  Assault Offenses  Simple Assault          NaN
# 499875  2015-05-01       1915         Vandalism       Vandalism          NaN
# 499876  2015-05-01       1915  Assault Offenses    Intimidation          NaN
# 499902  2015-05-01       1200      Sex Offenses  Statutory Rape          NaN
# 499907  2015-05-01       2126  Assault Offenses  Simple Assault          NaN
#
#         OpenDataLon  OpenDataX  OpenDataY  ReportDate  OffenseCount
# 52              NaN        NaN        NaN  2023-06-30             1
# 53              NaN        NaN        NaN  2023-06-30             1
# 55              NaN        NaN        NaN  2023-06-30             2
# 56              NaN        NaN        NaN  2023-06-30             1
# 78              NaN        NaN        NaN  2023-06-30             1
# ...             ...        ...        ...         ...           ...
# 499874          NaN        NaN        NaN  2015-05-01             1
# 499875          NaN        NaN        NaN  2015-05-01             1
# 499876          NaN        NaN        NaN  2015-05-01             1
# 499902          NaN        NaN        NaN  2015-05-01             1
# 499907          NaN        NaN        NaN  2015-05-01             1
#
# [42237 rows x 15 columns]

# %%
df.loc[df["Neighborhood"] == "Centennial"]
# Out:
#         Unnamed: 0                        Address   CaseNumber CrimeAgainst  \
# 55          470561                            NaN  23-X5852364       Person
# 56          470560                            NaN  23-X5852363       Person
# 105         495639  16300 BLOCK OF SE DIVISION ST    23-915210     Property
# 151         470549                            NaN  23-X5851899       Person
# 181         484503     3800 BLOCK OF SE 149TH AVE    23-170834     Property
# ...            ...                            ...          ...          ...
# 499720       31827  14600 BLOCK OF SE DIVISION ST    15-145026     Property
# 499738       12700     1600 BLOCK OF SE 162ND AVE    15-144270     Property
# 499791          10                            NaN  15-X4283397       Person
# 499850       32349     16100 BLOCK OF SE STARK ST    15-143311     Property
# 499852       32348     16100 BLOCK OF SE STARK ST    15-143311       Person
#
#        Neighborhood   OccurDate  OccurTime      OffenseCategory  \
# 55       Centennial  2023-06-30       2200     Assault Offenses
# 56       Centennial  2023-06-30       2038     Assault Offenses
# 105      Centennial  2023-06-30       1910     Larceny Offenses
# 151      Centennial  2023-06-29       2125     Assault Offenses
# 181      Centennial  2023-06-29        900  Motor Vehicle Theft
# ...             ...         ...        ...                  ...
# 499720   Centennial  2015-05-02       2248     Larceny Offenses
# 499738   Centennial  2015-05-02       2100  Motor Vehicle Theft
# 499791   Centennial  2015-05-01       2033     Assault Offenses
# 499850   Centennial  2015-05-01       1430       Fraud Offenses
# 499852   Centennial  2015-05-01       1430     Assault Offenses
#
#                                     OffenseType  OpenDataLat  OpenDataLon  \
# 55                                 Intimidation          NaN          NaN
# 56                                 Intimidation          NaN          NaN
# 105                                 Shoplifting    45.504619  -122.495377
# 151                              Simple Assault          NaN          NaN
# 181                         Motor Vehicle Theft    45.494620  -122.509787
# ...                                         ...          ...          ...
# 499720                      Theft From Building    45.504288  -122.512275
# 499738                      Motor Vehicle Theft    45.510907  -122.496609
# 499791                           Simple Assault          NaN          NaN
# 499850  False Pretenses/Swindle/Confidence Game    45.519112  -122.496819
# 499852                             Intimidation    45.519112  -122.496819
#
#         OpenDataX  OpenDataY  ReportDate  OffenseCount
# 55            NaN        NaN  2023-06-30             2
# 56            NaN        NaN  2023-06-30             1
# 105     7690576.0   676388.0  2023-06-30             1
# 151           NaN        NaN  2023-06-29             1
# 181     7686792.0   672835.0  2023-06-29             1
# ...           ...        ...         ...           ...
# 499720  7686242.0   676375.0  2015-05-02             1
# 499738  7690317.0   678688.0  2015-05-02             1
# 499791        NaN        NaN  2015-05-01             1
# 499850  7690337.0   681680.0  2015-05-01             1
# 499852  7690337.0   681680.0  2015-05-01             1
#
# [15061 rows x 15 columns]
